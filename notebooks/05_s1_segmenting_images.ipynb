# %% [markdown]
# # Capstone project by Sebastien Peytrignet
#
# # Trash or Treasure? Using machine learning to classify and segment images of litter
#
# # Notebook 3: Segmentation problem C.1 - segmenting bottles

# %% [markdown]
# ## 1) Load packages

# %% [markdown]
# We start by loading a standard set of Python libraries, and install and load [keras_unet](https://github.com/karolzak/keras-unet), a package for image segmentation tasks with a number of useful helper functions.

# %%
# %matplotlib inline
import os
import json
import cv2
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
pip install keras_unet
# Out:
# Collecting keras_unet
#   Downloading keras_unet-0.1.2-py3-none-any.whl (16 kB)
# Installing collected packages: keras_unet
# Successfully installed keras_unet-0.1.2

# %%
import keras_unet
# Out:
# -----------------------------------------
# keras-unet init: TF version is >= 2.0.0 - using `tf.keras` instead of `Keras`
# -----------------------------------------

# %% [markdown]
# ## 2) Load data for segmentation model

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Dataset path
dataset_path = '/content/drive/MyDrive/TACO'

# %%
# Dataset path
features_path = '/content/drive/MyDrive/TACO features'

# %% [markdown]
# Next, we load the images and masks for the images of bottles we set aside in notebooks 1 and 2.
#
# We use the images created with **widen_param=0.2**, meaning that our objects will be in the **center of the image** but we retain some of the **image background** beyond the annotation bounding box. As a reminder, we also restricted the sample to images with **only one bottle**. Therefore, the model will not encounter any images containing two or more objects to segment.

# %%
# Load the processed (cropped+framed) images
with np.load("{}/{}/{}".format(features_path,"widen_param_0.2","classification-images.npz"), allow_pickle=True) as npz_file:
    # It's a dictionary-like object
    print(list(npz_file.keys()))

    # Load the arrays
    s1_images = npz_file["s1"]
    s1_masks = npz_file["s1_masks"]
# Out:
# ['c1', 'c2', 's1', 's1_masks']

# %% [markdown]
# ## 3) Plotting images (X) and masks (Y)

# %% [markdown]
# The image masks have the same shape as the corresponding images (224x224 pixels), and each pixel has either a value of 0 (if it's outside of the object) or 1 (if it's inside of the object). A key difference is that our images are in colour (and therefore have three colour channels) whereas the masks only have one colour channel or dimension.
#
# We rescale the images so the value in each image pixel is between 0 and 1, and set set the data type for the masks to integers.

# %%
s1_masks = s1_masks.astype(np.uint8)

# %%
s1_images = s1_images*1./255.

# %%
"Shape of images array: {}, Shape of masks array: {}".format(s1_images.shape,s1_masks.shape)
# Out:
# 'Shape of images array: (248, 224, 224, 3), Shape of masks array: (248, 224, 224, 1)'

# %% [markdown]
# Then we plot 10 images from our set using the plot_imgs function, showing the original image and its mask side by side. We also show the overlay, with the mask on top of the original image. This is a useful sense check, to verify that our images and masks have been processed properly.

# %%
from keras_unet.utils import plot_imgs

plot_imgs(org_imgs=s1_images, mask_imgs=s1_masks, nm_img_to_plot=10, figsize=2)

# %% [markdown]
# ## 4) Splitting data into train, validation and test sets

# %% [markdown]
# In these models, our predictors (X) will be the images and the outcome (Y) will be the image masks. As opposed to our previous classification problems, here we will be making predictions at the _pixel_ level rather than at the image level. Indeed, we are predicting whether each pixel is located inside the bottle (Y=1) or outside the bottle (Y=0).

# %% [markdown]
# First, we split the data into two sets: a combined training/validation set (90%) and a test set (10%).
#
# Then, we split the combined training/validation set into training (80%) and validation sets (20%).
#
# The resulting training set has 178 images, the validation set has 45 images and the testing set has 25 images.

# %%
from sklearn.model_selection import train_test_split

x_trainval, x_test, y_trainval, y_test = train_test_split(s1_images, s1_masks, test_size=0.1, random_state=8)

print("x_test: {}, y_test: {}".format(x_test.shape,y_test.shape))
# Out:
# x_test: (25, 224, 224, 3), y_test: (25, 224, 224, 1)

# %%
x_train, x_val, y_train, y_val = train_test_split(x_trainval, y_trainval, test_size=0.2, random_state=8)

print("x_train: {}, y_train: {}".format(x_train.shape,y_train.shape))
print("x_val: {}, y_val: {}".format(x_val.shape,y_val.shape))

del x_trainval
del y_trainval
# Out:
# x_train: (178, 224, 224, 3), y_train: (178, 224, 224, 1)
# x_val: (45, 224, 224, 3), y_val: (45, 224, 224, 1)

# %% [markdown]
# ## 5) Setting up a convolutional neural network for image segmentation

# %%
import tensorflow as tf
from tensorflow import keras
from tensorflow.python.keras.models import Sequential
from tensorflow.python.keras.callbacks import ModelCheckpoint, EarlyStopping
from tensorflow.keras.layers import Conv2D, BatchNormalization, Activation, MaxPool2D, Conv2DTranspose, Concatenate, Input, Dropout
from tensorflow.keras.models import Model

# %% [markdown]
# We specify a convolutional neural network with a U-net architecture for our segmentation task. The code to specify the model architecture was found in a [tutorial](https://www.machinelearningnuggets.com/image-segmentation-with-u-net-define-u-net-model-from-scratch-in-keras-and-tensorflow/) on image segmentation using Keras written by Derrick Mwiti.
#
# First, the model receives an input image of size 224x224x3, representing the three colour channels.
#
# Then, there is a contraction path which involves downsampling the input image and extracting increasingly abstract features. The number of filters in each block goes from 16 to 256. Between each block, a Max Pooling operation with stride 2 reduces the spatial resolution by half.
#
# Traditional convolutional neural networks with pooling layers and dense layers are not suitable for image segmentation tasks because they discard **spatial information**, which is important to identify *where* objects are located in an image. U-Net models, however, are designed to preserve spatial information by upsampling the image, which enables the model to capture *where* objects might be located.
#
# Following the contraction path, the expansive path involves upsampling the features back to the original image size using transposed convolutions. Finally, a sigmoid activation function generates the binary segmentation mask.

# %%
### Inputs ###

inputs = tf.keras.layers.Input((224, 224, 3))

### Contraction path ###

  #16 filters#
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(inputs)
c1 = tf.keras.layers.Dropout(0.1)(c1)
c1 = tf.keras.layers.Conv2D(16, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c1)
b1 = tf.keras.layers.BatchNormalization()(c1)
r1 = tf.keras.layers.ReLU()(b1)
p1 = tf.keras.layers.MaxPooling2D((2, 2))(r1)

  #32 filters#
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p1)
c2 = tf.keras.layers.Dropout(0.1)(c2)
c2 = tf.keras.layers.Conv2D(32, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c2)
b2 = tf.keras.layers.BatchNormalization()(c2)
r2 = tf.keras.layers.ReLU()(b2)
p2 = tf.keras.layers.MaxPooling2D((2, 2))(r2)

  #64 filters#
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p2)
c3 = tf.keras.layers.Dropout(0.2)(c3)
c3 = tf.keras.layers.Conv2D(64, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c3)
b3 = tf.keras.layers.BatchNormalization()(c3)
r3 = tf.keras.layers.ReLU()(b3)
p3 = tf.keras.layers.MaxPooling2D((2, 2))(r3)

  #128 filters#
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p3)
c4 = tf.keras.layers.Dropout(0.2)(c4)
c4 = tf.keras.layers.Conv2D(128, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c4)
b4 = tf.keras.layers.BatchNormalization()(c4)
r4 = tf.keras.layers.ReLU()(b4)
p4 = tf.keras.layers.MaxPooling2D(pool_size=(2, 2))(r4)

  #256 filters#
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(p4)
b5 = tf.keras.layers.BatchNormalization()(c5)
r5 = tf.keras.layers.ReLU()(b5)
c5 = tf.keras.layers.Dropout(0.3)(r5)
c5 = tf.keras.layers.Conv2D(256, (3, 3), activation='relu', kernel_initializer='he_normal', padding='same')(c5)

### Expansive path ###

  #128 filters#
u6 = tf.keras.layers.Conv2DTranspose(128, (2, 2), strides=(2, 2), padding='same')(c5)
u6 = tf.keras.layers.concatenate([u6, c4])
u6 = tf.keras.layers.BatchNormalization()(u6)
u6 = tf.keras.layers.ReLU()(u6)

  #64 filters#
u7 = tf.keras.layers.Conv2DTranspose(64, (2, 2), strides=(2, 2), padding='same')(u6)
u7 = tf.keras.layers.concatenate([u7, c3])
u7 = tf.keras.layers.BatchNormalization()(u7)
u7 = tf.keras.layers.ReLU()(u7)

  #32 filters#
u8 = tf.keras.layers.Conv2DTranspose(32, (2, 2), strides=(2, 2), padding='same')(u7)
u8 = tf.keras.layers.concatenate([u8, c2])
u8 = tf.keras.layers.BatchNormalization()(u8)
u8 = tf.keras.layers.ReLU()(u8)

  #16 filters#
u9 = tf.keras.layers.Conv2DTranspose(16, (2, 2), strides=(2, 2), padding='same')(u8)
u9 = tf.keras.layers.concatenate([u9, c1], axis=3)
u9 = tf.keras.layers.BatchNormalization()(u9)
u9 = tf.keras.layers.ReLU()(u9)

### Outputs ###

outputs = tf.keras.layers.Conv2D(1, (1, 1), activation='sigmoid')(u9)

# %%
unet_model = tf.keras.Model(inputs=[inputs], outputs=[outputs])

# %% [markdown]
# We also plot the model architecture (flipped on its side). We can clearly see both the contraction and expansive paths. The concatenate step combine high-level features from the contraction path with low-level details from the expansive path.

# %%
tf.keras.utils.plot_model(unet_model)

# %% [markdown]
# ## 6) Data augmentation

# %% [markdown]
# We will use the 'get_augmented' function from the keras_unet package to artificially augment our training data. By generating "new" images, data augmentation can improve the model's performance and generalizability. This helps the model learn more robust representations of the data and reduce overfitting.

# %%
from keras_unet.utils import get_augmented

train_gen = get_augmented(
    x_train, y_train,
    batch_size=3,
    data_gen_args = dict(
        rotation_range=5.,
        width_shift_range=0.05,
        height_shift_range=0.05,
        shear_range=40,
        zoom_range=0.2,
        horizontal_flip=True,
        vertical_flip=False,
        fill_mode='constant'
    ))

# %% [markdown]
# Our augmented images generator output three images at a time, and we plot a sample of those augmented images to check that the spatial relationships in the masks have been preserved.

# %%
sample_batch = next(train_gen)
xx, yy = sample_batch
print(xx.shape, yy.shape)

plot_imgs(org_imgs=xx, mask_imgs=yy, nm_img_to_plot=3, figsize=2)
# Out:
# (3, 224, 224, 3) (3, 224, 224, 1)

# %% [markdown]
# ## 7) Fitting our model

# %% [markdown]
# ### The IOU metric

# %% [markdown]
# The intersection-over-union (IoU) metric is a widely used metric to assess the performance of an image segmentation model. It measures the overlap between the predicted segmentation mask and the ground truth mask for an image. IoU ranges from 0 to 1, with 0 meaning no overlap and 1 meaning a perfect overlap.
#
# ![iou](https://b2633864.smushcdn.com/2633864/wp-content/uploads/2016/09/iou_examples.png?lossy=2&strip=1&webp=1)
#
# *Adrian Rosebrock, "Intersection over union for object detection" ([link](https://pyimagesearch.com/2016/11/07/intersection-over-union-iou-for-object-detection/))*

# %% [markdown]
# The [thresholded IOU](https://github.com/karolzak/keras-unet/blob/master/keras_unet/metrics.py) metric applies a threshold of 0.5 by default to each pixel-level prediction before computing the IOU.

# %% [markdown]
# ### Compiling and fitting the model

# %%
from keras.callbacks import ModelCheckpoint
from keras.optimizers import Adam
from keras_unet.metrics import iou, iou_thresholded

# %% [markdown]
# Using a model checkpoint, we will save the model weights each time the thresholded IOU improves on the validation set images.

# %%
model_path = "{}/{}/{}".format(features_path,"widen_param_0.2","segm_model.h5")

callback_checkpoint = ModelCheckpoint(
    model_path,
    verbose=1,
    monitor='val_iou_thresholded',
    mode='max',
    save_best_only=True,
)

# %% [markdown]
# We will use a binary cross-entropy loss function, since this is a pixel-level binary classification problem.
#
# Our data generator provides the model with training data in batches, with each batch consisting of three input images and masks. Our generator provides 300 batches per epoch, and the model is trained for 150 epochs. As a reminder, there are 178 images in the training set, so each epoch will see at least one version of each image. This allows the model to slowly improve its performance over 150 iterations.

# %%
unet_model.compile(
    optimizer=Adam(),
    loss='binary_crossentropy',
    metrics=[iou, iou_thresholded]
)

# %%
tf.keras.utils.set_random_seed(1)

# %% [markdown]
# Finally, we fit our convolutional neural network with a U-net architecture.

# %%
history = unet_model.fit(
    train_gen,
    steps_per_epoch=300,
    validation_data=(x_val, y_val),
    epochs=150,
    callbacks=[callback_checkpoint]
)
# Out:
# Epoch 1/150
# 300/300 [==============================] - ETA: 0s - loss: 0.3093 - iou: 0.1613 - iou_thresholded: 0.3034
# Epoch 1: val_iou_thresholded improved from -inf to 0.32476, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(
# 300/300 [==============================] - 43s 72ms/step - loss: 0.3093 - iou: 0.1613 - iou_thresholded: 0.3034 - val_loss: 0.3101 - val_iou: 0.2107 - val_iou_thresholded: 0.3248
# Epoch 2/150
# 300/300 [==============================] - ETA: 0s - loss: 0.2030 - iou: 0.2613 - iou_thresholded: 0.4115
# Epoch 2: val_iou_thresholded did not improve from 0.32476
# 300/300 [==============================] - 19s 62ms/step - loss: 0.2030 - iou: 0.2613 - iou_thresholded: 0.4115 - val_loss: 0.1988 - val_iou: 0.2378 - val_iou_thresholded: 0.2888
# Epoch 3/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1753 - iou: 0.3213 - iou_thresholded: 0.4645
# Epoch 3: val_iou_thresholded did not improve from 0.32476
# 300/300 [==============================] - 20s 67ms/step - loss: 0.1753 - iou: 0.3213 - iou_thresholded: 0.4645 - val_loss: 0.2380 - val_iou: 0.1524 - val_iou_thresholded: 0.0986
# Epoch 4/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1560 - iou: 0.3660 - iou_thresholded: 0.5144
# Epoch 4: val_iou_thresholded improved from 0.32476 to 0.43708, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 20s 67ms/step - loss: 0.1560 - iou: 0.3660 - iou_thresholded: 0.5144 - val_loss: 0.1588 - val_iou: 0.3189 - val_iou_thresholded: 0.4371
# Epoch 5/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1478 - iou: 0.3875 - iou_thresholded: 0.5273
# Epoch 5: val_iou_thresholded improved from 0.43708 to 0.45147, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 20s 66ms/step - loss: 0.1478 - iou: 0.3875 - iou_thresholded: 0.5273 - val_loss: 0.1649 - val_iou: 0.3296 - val_iou_thresholded: 0.4515
# Epoch 6/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1304 - iou: 0.4261 - iou_thresholded: 0.5696
# Epoch 6: val_iou_thresholded improved from 0.45147 to 0.45210, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 21s 69ms/step - loss: 0.1304 - iou: 0.4261 - iou_thresholded: 0.5696 - val_loss: 0.1638 - val_iou: 0.3870 - val_iou_thresholded: 0.4521
# Epoch 7/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1354 - iou: 0.4250 - iou_thresholded: 0.5593
# Epoch 7: val_iou_thresholded improved from 0.45210 to 0.48650, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 21s 69ms/step - loss: 0.1354 - iou: 0.4250 - iou_thresholded: 0.5593 - val_loss: 0.1433 - val_iou: 0.3872 - val_iou_thresholded: 0.4865
# Epoch 8/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1198 - iou: 0.4636 - iou_thresholded: 0.5997
# Epoch 8: val_iou_thresholded did not improve from 0.48650
# 300/300 [==============================] - 18s 61ms/step - loss: 0.1198 - iou: 0.4636 - iou_thresholded: 0.5997 - val_loss: 0.1705 - val_iou: 0.3781 - val_iou_thresholded: 0.4380
# Epoch 9/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1153 - iou: 0.4795 - iou_thresholded: 0.6140
# Epoch 9: val_iou_thresholded did not improve from 0.48650
# 300/300 [==============================] - 18s 62ms/step - loss: 0.1153 - iou: 0.4795 - iou_thresholded: 0.6140 - val_loss: 0.1626 - val_iou: 0.3925 - val_iou_thresholded: 0.4649
# Epoch 10/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1120 - iou: 0.4870 - iou_thresholded: 0.6174
# Epoch 10: val_iou_thresholded did not improve from 0.48650
# 300/300 [==============================] - 18s 62ms/step - loss: 0.1120 - iou: 0.4870 - iou_thresholded: 0.6174 - val_loss: 0.1481 - val_iou: 0.4079 - val_iou_thresholded: 0.4706
# Epoch 11/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1053 - iou: 0.5062 - iou_thresholded: 0.6418
# Epoch 11: val_iou_thresholded improved from 0.48650 to 0.49745, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 19s 64ms/step - loss: 0.1053 - iou: 0.5062 - iou_thresholded: 0.6418 - val_loss: 0.1429 - val_iou: 0.4001 - val_iou_thresholded: 0.4974
# Epoch 12/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1025 - iou: 0.5182 - iou_thresholded: 0.6471
# Epoch 12: val_iou_thresholded improved from 0.49745 to 0.51406, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 21s 69ms/step - loss: 0.1025 - iou: 0.5182 - iou_thresholded: 0.6471 - val_loss: 0.1547 - val_iou: 0.4375 - val_iou_thresholded: 0.5141
# Epoch 13/150
# 300/300 [==============================] - ETA: 0s - loss: 0.1023 - iou: 0.5181 - iou_thresholded: 0.6435
# Epoch 13: val_iou_thresholded did not improve from 0.51406
# 300/300 [==============================] - 18s 61ms/step - loss: 0.1023 - iou: 0.5181 - iou_thresholded: 0.6435 - val_loss: 0.1445 - val_iou: 0.4163 - val_iou_thresholded: 0.4816
# Epoch 14/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0953 - iou: 0.5348 - iou_thresholded: 0.6636
# Epoch 14: val_iou_thresholded did not improve from 0.51406
# 300/300 [==============================] - 19s 62ms/step - loss: 0.0953 - iou: 0.5348 - iou_thresholded: 0.6636 - val_loss: 0.1413 - val_iou: 0.4360 - val_iou_thresholded: 0.5128
# Epoch 15/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0912 - iou: 0.5517 - iou_thresholded: 0.6769
# Epoch 15: val_iou_thresholded did not improve from 0.51406
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0912 - iou: 0.5517 - iou_thresholded: 0.6769 - val_loss: 0.1642 - val_iou: 0.4406 - val_iou_thresholded: 0.5006
# Epoch 16/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0841 - iou: 0.5719 - iou_thresholded: 0.6874
# Epoch 16: val_iou_thresholded improved from 0.51406 to 0.54981, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0841 - iou: 0.5719 - iou_thresholded: 0.6874 - val_loss: 0.1445 - val_iou: 0.4790 - val_iou_thresholded: 0.5498
# Epoch 17/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0824 - iou: 0.5773 - iou_thresholded: 0.6931
# Epoch 17: val_iou_thresholded improved from 0.54981 to 0.55381, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 21s 69ms/step - loss: 0.0824 - iou: 0.5773 - iou_thresholded: 0.6931 - val_loss: 0.1482 - val_iou: 0.4738 - val_iou_thresholded: 0.5538
# Epoch 18/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0799 - iou: 0.5893 - iou_thresholded: 0.7053
# Epoch 18: val_iou_thresholded improved from 0.55381 to 0.58165, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0799 - iou: 0.5893 - iou_thresholded: 0.7053 - val_loss: 0.1317 - val_iou: 0.5021 - val_iou_thresholded: 0.5816
# Epoch 19/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0759 - iou: 0.6017 - iou_thresholded: 0.7131
# Epoch 19: val_iou_thresholded did not improve from 0.58165
# 300/300 [==============================] - 19s 62ms/step - loss: 0.0759 - iou: 0.6017 - iou_thresholded: 0.7131 - val_loss: 0.1327 - val_iou: 0.4792 - val_iou_thresholded: 0.5570
# Epoch 20/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0787 - iou: 0.6001 - iou_thresholded: 0.7150
# Epoch 20: val_iou_thresholded did not improve from 0.58165
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0787 - iou: 0.6001 - iou_thresholded: 0.7150 - val_loss: 0.1449 - val_iou: 0.4386 - val_iou_thresholded: 0.5158
# Epoch 21/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0736 - iou: 0.6163 - iou_thresholded: 0.7232
# Epoch 21: val_iou_thresholded did not improve from 0.58165
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0736 - iou: 0.6163 - iou_thresholded: 0.7232 - val_loss: 0.1674 - val_iou: 0.4735 - val_iou_thresholded: 0.5219
# Epoch 22/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0657 - iou: 0.6461 - iou_thresholded: 0.7452
# Epoch 22: val_iou_thresholded did not improve from 0.58165
# 300/300 [==============================] - 20s 67ms/step - loss: 0.0657 - iou: 0.6461 - iou_thresholded: 0.7452 - val_loss: 0.1758 - val_iou: 0.4481 - val_iou_thresholded: 0.5005
# Epoch 23/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0662 - iou: 0.6394 - iou_thresholded: 0.7401
# Epoch 23: val_iou_thresholded did not improve from 0.58165
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0662 - iou: 0.6394 - iou_thresholded: 0.7401 - val_loss: 0.1408 - val_iou: 0.5011 - val_iou_thresholded: 0.5475
# Epoch 24/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0592 - iou: 0.6678 - iou_thresholded: 0.7629
# Epoch 24: val_iou_thresholded did not improve from 0.58165
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0592 - iou: 0.6678 - iou_thresholded: 0.7629 - val_loss: 0.1293 - val_iou: 0.4866 - val_iou_thresholded: 0.5412
# Epoch 25/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0698 - iou: 0.6354 - iou_thresholded: 0.7368
# Epoch 25: val_iou_thresholded improved from 0.58165 to 0.59253, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0698 - iou: 0.6354 - iou_thresholded: 0.7368 - val_loss: 0.1263 - val_iou: 0.5237 - val_iou_thresholded: 0.5925
# Epoch 26/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0597 - iou: 0.6746 - iou_thresholded: 0.7674
# Epoch 26: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0597 - iou: 0.6746 - iou_thresholded: 0.7674 - val_loss: 0.1426 - val_iou: 0.5018 - val_iou_thresholded: 0.5623
# Epoch 27/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0607 - iou: 0.6664 - iou_thresholded: 0.7589
# Epoch 27: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0607 - iou: 0.6664 - iou_thresholded: 0.7589 - val_loss: 0.1469 - val_iou: 0.4982 - val_iou_thresholded: 0.5484
# Epoch 28/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0581 - iou: 0.6775 - iou_thresholded: 0.7673
# Epoch 28: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0581 - iou: 0.6775 - iou_thresholded: 0.7673 - val_loss: 0.1349 - val_iou: 0.4936 - val_iou_thresholded: 0.5530
# Epoch 29/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0599 - iou: 0.6779 - iou_thresholded: 0.7698
# Epoch 29: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0599 - iou: 0.6779 - iou_thresholded: 0.7698 - val_loss: 0.1662 - val_iou: 0.4644 - val_iou_thresholded: 0.5173
# Epoch 30/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0539 - iou: 0.6961 - iou_thresholded: 0.7845
# Epoch 30: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 18s 60ms/step - loss: 0.0539 - iou: 0.6961 - iou_thresholded: 0.7845 - val_loss: 0.1591 - val_iou: 0.4693 - val_iou_thresholded: 0.5102
# Epoch 31/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0517 - iou: 0.6980 - iou_thresholded: 0.7840
# Epoch 31: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 18s 60ms/step - loss: 0.0517 - iou: 0.6980 - iou_thresholded: 0.7840 - val_loss: 0.1506 - val_iou: 0.4699 - val_iou_thresholded: 0.5270
# Epoch 32/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0646 - iou: 0.6544 - iou_thresholded: 0.7478
# Epoch 32: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0646 - iou: 0.6544 - iou_thresholded: 0.7478 - val_loss: 0.1449 - val_iou: 0.5097 - val_iou_thresholded: 0.5716
# Epoch 33/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0510 - iou: 0.7082 - iou_thresholded: 0.7938
# Epoch 33: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0510 - iou: 0.7082 - iou_thresholded: 0.7938 - val_loss: 0.1410 - val_iou: 0.5094 - val_iou_thresholded: 0.5597
# Epoch 34/150
# 299/300 [============================>.] - ETA: 0s - loss: 0.0489 - iou: 0.7211 - iou_thresholded: 0.8009
# Epoch 34: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0490 - iou: 0.7208 - iou_thresholded: 0.8006 - val_loss: 0.1515 - val_iou: 0.5119 - val_iou_thresholded: 0.5642
# Epoch 35/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0545 - iou: 0.6953 - iou_thresholded: 0.7812
# Epoch 35: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0545 - iou: 0.6953 - iou_thresholded: 0.7812 - val_loss: 0.1409 - val_iou: 0.4981 - val_iou_thresholded: 0.5413
# Epoch 36/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0561 - iou: 0.6885 - iou_thresholded: 0.7737
# Epoch 36: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0561 - iou: 0.6885 - iou_thresholded: 0.7737 - val_loss: 0.1367 - val_iou: 0.5247 - val_iou_thresholded: 0.5801
# Epoch 37/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0498 - iou: 0.7043 - iou_thresholded: 0.7867
# Epoch 37: val_iou_thresholded did not improve from 0.59253
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0498 - iou: 0.7043 - iou_thresholded: 0.7867 - val_loss: 0.1365 - val_iou: 0.5425 - val_iou_thresholded: 0.5914
# Epoch 38/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0481 - iou: 0.7155 - iou_thresholded: 0.7925
# Epoch 38: val_iou_thresholded improved from 0.59253 to 0.59654, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 20s 65ms/step - loss: 0.0481 - iou: 0.7155 - iou_thresholded: 0.7925 - val_loss: 0.1320 - val_iou: 0.5283 - val_iou_thresholded: 0.5965
# Epoch 39/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0503 - iou: 0.7168 - iou_thresholded: 0.7984
# Epoch 39: val_iou_thresholded did not improve from 0.59654
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0503 - iou: 0.7168 - iou_thresholded: 0.7984 - val_loss: 0.1552 - val_iou: 0.5034 - val_iou_thresholded: 0.5474
# Epoch 40/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0449 - iou: 0.7323 - iou_thresholded: 0.8085
# Epoch 40: val_iou_thresholded improved from 0.59654 to 0.60126, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 20s 65ms/step - loss: 0.0449 - iou: 0.7323 - iou_thresholded: 0.8085 - val_loss: 0.1345 - val_iou: 0.5501 - val_iou_thresholded: 0.6013
# Epoch 41/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0423 - iou: 0.7440 - iou_thresholded: 0.8165
# Epoch 41: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 22s 72ms/step - loss: 0.0423 - iou: 0.7440 - iou_thresholded: 0.8165 - val_loss: 0.1468 - val_iou: 0.5344 - val_iou_thresholded: 0.5840
# Epoch 42/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0379 - iou: 0.7657 - iou_thresholded: 0.8333
# Epoch 42: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0379 - iou: 0.7657 - iou_thresholded: 0.8333 - val_loss: 0.1435 - val_iou: 0.5444 - val_iou_thresholded: 0.5804
# Epoch 43/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0432 - iou: 0.7458 - iou_thresholded: 0.8179
# Epoch 43: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 20s 67ms/step - loss: 0.0432 - iou: 0.7458 - iou_thresholded: 0.8179 - val_loss: 0.1492 - val_iou: 0.5339 - val_iou_thresholded: 0.5837
# Epoch 44/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0472 - iou: 0.7293 - iou_thresholded: 0.8073
# Epoch 44: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0472 - iou: 0.7293 - iou_thresholded: 0.8073 - val_loss: 0.1351 - val_iou: 0.5332 - val_iou_thresholded: 0.5809
# Epoch 45/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0407 - iou: 0.7548 - iou_thresholded: 0.8250
# Epoch 45: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0407 - iou: 0.7548 - iou_thresholded: 0.8250 - val_loss: 0.1354 - val_iou: 0.5426 - val_iou_thresholded: 0.5877
# Epoch 46/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0389 - iou: 0.7653 - iou_thresholded: 0.8337
# Epoch 46: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0389 - iou: 0.7653 - iou_thresholded: 0.8337 - val_loss: 0.1735 - val_iou: 0.5003 - val_iou_thresholded: 0.5320
# Epoch 47/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0463 - iou: 0.7316 - iou_thresholded: 0.8070
# Epoch 47: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0463 - iou: 0.7316 - iou_thresholded: 0.8070 - val_loss: 0.1499 - val_iou: 0.4980 - val_iou_thresholded: 0.5413
# Epoch 48/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0419 - iou: 0.7535 - iou_thresholded: 0.8253
# Epoch 48: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0419 - iou: 0.7535 - iou_thresholded: 0.8253 - val_loss: 0.1364 - val_iou: 0.5310 - val_iou_thresholded: 0.5736
# Epoch 49/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0361 - iou: 0.7703 - iou_thresholded: 0.8353
# Epoch 49: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0361 - iou: 0.7703 - iou_thresholded: 0.8353 - val_loss: 0.1402 - val_iou: 0.5302 - val_iou_thresholded: 0.5594
# Epoch 50/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0346 - iou: 0.7822 - iou_thresholded: 0.8456
# Epoch 50: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0346 - iou: 0.7822 - iou_thresholded: 0.8456 - val_loss: 0.1471 - val_iou: 0.5459 - val_iou_thresholded: 0.5764
# Epoch 51/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0361 - iou: 0.7708 - iou_thresholded: 0.8363
# Epoch 51: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 18s 60ms/step - loss: 0.0361 - iou: 0.7708 - iou_thresholded: 0.8363 - val_loss: 0.1767 - val_iou: 0.5125 - val_iou_thresholded: 0.5526
# Epoch 52/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0470 - iou: 0.7284 - iou_thresholded: 0.8024
# Epoch 52: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 19s 62ms/step - loss: 0.0470 - iou: 0.7284 - iou_thresholded: 0.8024 - val_loss: 0.1557 - val_iou: 0.5056 - val_iou_thresholded: 0.5375
# Epoch 53/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0407 - iou: 0.7546 - iou_thresholded: 0.8257
# Epoch 53: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0407 - iou: 0.7546 - iou_thresholded: 0.8257 - val_loss: 0.1493 - val_iou: 0.5370 - val_iou_thresholded: 0.5635
# Epoch 54/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0361 - iou: 0.7732 - iou_thresholded: 0.8383
# Epoch 54: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0361 - iou: 0.7732 - iou_thresholded: 0.8383 - val_loss: 0.1588 - val_iou: 0.5223 - val_iou_thresholded: 0.5487
# Epoch 55/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0463 - iou: 0.7447 - iou_thresholded: 0.8238
# Epoch 55: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 26s 86ms/step - loss: 0.0463 - iou: 0.7447 - iou_thresholded: 0.8238 - val_loss: 0.1390 - val_iou: 0.5440 - val_iou_thresholded: 0.5806
# Epoch 56/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0337 - iou: 0.7876 - iou_thresholded: 0.8497
# Epoch 56: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 21s 69ms/step - loss: 0.0337 - iou: 0.7876 - iou_thresholded: 0.8497 - val_loss: 0.1425 - val_iou: 0.5523 - val_iou_thresholded: 0.5938
# Epoch 57/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0350 - iou: 0.7813 - iou_thresholded: 0.8430
# Epoch 57: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 21s 69ms/step - loss: 0.0350 - iou: 0.7813 - iou_thresholded: 0.8430 - val_loss: 0.1430 - val_iou: 0.5530 - val_iou_thresholded: 0.5871
# Epoch 58/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0325 - iou: 0.7927 - iou_thresholded: 0.8528
# Epoch 58: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 27s 91ms/step - loss: 0.0325 - iou: 0.7927 - iou_thresholded: 0.8528 - val_loss: 0.1387 - val_iou: 0.5618 - val_iou_thresholded: 0.5936
# Epoch 59/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0389 - iou: 0.7705 - iou_thresholded: 0.8358
# Epoch 59: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0389 - iou: 0.7705 - iou_thresholded: 0.8358 - val_loss: 0.1471 - val_iou: 0.5378 - val_iou_thresholded: 0.5789
# Epoch 60/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0332 - iou: 0.7917 - iou_thresholded: 0.8530
# Epoch 60: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 20s 67ms/step - loss: 0.0332 - iou: 0.7917 - iou_thresholded: 0.8530 - val_loss: 0.1498 - val_iou: 0.5673 - val_iou_thresholded: 0.5939
# Epoch 61/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0337 - iou: 0.7883 - iou_thresholded: 0.8495
# Epoch 61: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0337 - iou: 0.7883 - iou_thresholded: 0.8495 - val_loss: 0.1571 - val_iou: 0.5372 - val_iou_thresholded: 0.5659
# Epoch 62/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0406 - iou: 0.7625 - iou_thresholded: 0.8311
# Epoch 62: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 24s 79ms/step - loss: 0.0406 - iou: 0.7625 - iou_thresholded: 0.8311 - val_loss: 0.1505 - val_iou: 0.5166 - val_iou_thresholded: 0.5529
# Epoch 63/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0319 - iou: 0.7943 - iou_thresholded: 0.8560
# Epoch 63: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 19s 62ms/step - loss: 0.0319 - iou: 0.7943 - iou_thresholded: 0.8560 - val_loss: 0.1564 - val_iou: 0.5432 - val_iou_thresholded: 0.5727
# Epoch 64/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0319 - iou: 0.7985 - iou_thresholded: 0.8560
# Epoch 64: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 20s 67ms/step - loss: 0.0319 - iou: 0.7985 - iou_thresholded: 0.8560 - val_loss: 0.1592 - val_iou: 0.5105 - val_iou_thresholded: 0.5313
# Epoch 65/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0386 - iou: 0.7644 - iou_thresholded: 0.8308
# Epoch 65: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 21s 69ms/step - loss: 0.0386 - iou: 0.7644 - iou_thresholded: 0.8308 - val_loss: 0.1410 - val_iou: 0.5618 - val_iou_thresholded: 0.6002
# Epoch 66/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0315 - iou: 0.7990 - iou_thresholded: 0.8575
# Epoch 66: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0315 - iou: 0.7990 - iou_thresholded: 0.8575 - val_loss: 0.1363 - val_iou: 0.5464 - val_iou_thresholded: 0.5780
# Epoch 67/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0314 - iou: 0.7995 - iou_thresholded: 0.8580
# Epoch 67: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0314 - iou: 0.7995 - iou_thresholded: 0.8580 - val_loss: 0.1529 - val_iou: 0.5343 - val_iou_thresholded: 0.5625
# Epoch 68/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0393 - iou: 0.7638 - iou_thresholded: 0.8287
# Epoch 68: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0393 - iou: 0.7638 - iou_thresholded: 0.8287 - val_loss: 0.1533 - val_iou: 0.5255 - val_iou_thresholded: 0.5581
# Epoch 69/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0298 - iou: 0.8081 - iou_thresholded: 0.8655
# Epoch 69: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 20s 68ms/step - loss: 0.0298 - iou: 0.8081 - iou_thresholded: 0.8655 - val_loss: 0.1390 - val_iou: 0.5517 - val_iou_thresholded: 0.5835
# Epoch 70/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0296 - iou: 0.8102 - iou_thresholded: 0.8646
# Epoch 70: val_iou_thresholded did not improve from 0.60126
# 300/300 [==============================] - 20s 68ms/step - loss: 0.0296 - iou: 0.8102 - iou_thresholded: 0.8646 - val_loss: 0.1665 - val_iou: 0.5268 - val_iou_thresholded: 0.5546
# Epoch 71/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0295 - iou: 0.8094 - iou_thresholded: 0.8657
# Epoch 71: val_iou_thresholded improved from 0.60126 to 0.61028, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0295 - iou: 0.8094 - iou_thresholded: 0.8657 - val_loss: 0.1457 - val_iou: 0.5761 - val_iou_thresholded: 0.6103
# Epoch 72/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0534 - iou: 0.7157 - iou_thresholded: 0.7959
# Epoch 72: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0534 - iou: 0.7157 - iou_thresholded: 0.7959 - val_loss: 0.1276 - val_iou: 0.5535 - val_iou_thresholded: 0.5962
# Epoch 73/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0329 - iou: 0.7948 - iou_thresholded: 0.8555
# Epoch 73: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 62ms/step - loss: 0.0329 - iou: 0.7948 - iou_thresholded: 0.8555 - val_loss: 0.1469 - val_iou: 0.5559 - val_iou_thresholded: 0.5889
# Epoch 74/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0294 - iou: 0.8067 - iou_thresholded: 0.8629
# Epoch 74: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 21s 71ms/step - loss: 0.0294 - iou: 0.8067 - iou_thresholded: 0.8629 - val_loss: 0.1477 - val_iou: 0.5409 - val_iou_thresholded: 0.5746
# Epoch 75/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0305 - iou: 0.8020 - iou_thresholded: 0.8591
# Epoch 75: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0305 - iou: 0.8020 - iou_thresholded: 0.8591 - val_loss: 0.1512 - val_iou: 0.5487 - val_iou_thresholded: 0.5770
# Epoch 76/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0276 - iou: 0.8192 - iou_thresholded: 0.8713
# Epoch 76: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0276 - iou: 0.8192 - iou_thresholded: 0.8713 - val_loss: 0.1611 - val_iou: 0.5364 - val_iou_thresholded: 0.5555
# Epoch 77/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0274 - iou: 0.8228 - iou_thresholded: 0.8745
# Epoch 77: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0274 - iou: 0.8228 - iou_thresholded: 0.8745 - val_loss: 0.1597 - val_iou: 0.5441 - val_iou_thresholded: 0.5730
# Epoch 78/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0302 - iou: 0.8107 - iou_thresholded: 0.8659
# Epoch 78: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0302 - iou: 0.8107 - iou_thresholded: 0.8659 - val_loss: 0.1505 - val_iou: 0.5489 - val_iou_thresholded: 0.5789
# Epoch 79/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0283 - iou: 0.8117 - iou_thresholded: 0.8683
# Epoch 79: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 21s 71ms/step - loss: 0.0283 - iou: 0.8117 - iou_thresholded: 0.8683 - val_loss: 0.1564 - val_iou: 0.5627 - val_iou_thresholded: 0.5896
# Epoch 80/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0277 - iou: 0.8216 - iou_thresholded: 0.8721
# Epoch 80: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0277 - iou: 0.8216 - iou_thresholded: 0.8721 - val_loss: 0.1467 - val_iou: 0.5684 - val_iou_thresholded: 0.6037
# Epoch 81/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0274 - iou: 0.8190 - iou_thresholded: 0.8728
# Epoch 81: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0274 - iou: 0.8190 - iou_thresholded: 0.8728 - val_loss: 0.1662 - val_iou: 0.5367 - val_iou_thresholded: 0.5623
# Epoch 82/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0284 - iou: 0.8132 - iou_thresholded: 0.8681
# Epoch 82: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0284 - iou: 0.8132 - iou_thresholded: 0.8681 - val_loss: 0.1787 - val_iou: 0.5209 - val_iou_thresholded: 0.5433
# Epoch 83/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0288 - iou: 0.8124 - iou_thresholded: 0.8659
# Epoch 83: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 21s 70ms/step - loss: 0.0288 - iou: 0.8124 - iou_thresholded: 0.8659 - val_loss: 0.1582 - val_iou: 0.5634 - val_iou_thresholded: 0.5923
# Epoch 84/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0270 - iou: 0.8209 - iou_thresholded: 0.8717
# Epoch 84: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 22s 73ms/step - loss: 0.0270 - iou: 0.8209 - iou_thresholded: 0.8717 - val_loss: 0.1517 - val_iou: 0.5595 - val_iou_thresholded: 0.5868
# Epoch 85/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0325 - iou: 0.7995 - iou_thresholded: 0.8567
# Epoch 85: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 21s 69ms/step - loss: 0.0325 - iou: 0.7995 - iou_thresholded: 0.8567 - val_loss: 0.1954 - val_iou: 0.5121 - val_iou_thresholded: 0.5473
# Epoch 86/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0304 - iou: 0.8075 - iou_thresholded: 0.8642
# Epoch 86: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0304 - iou: 0.8075 - iou_thresholded: 0.8642 - val_loss: 0.1319 - val_iou: 0.5595 - val_iou_thresholded: 0.5957
# Epoch 87/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0266 - iou: 0.8250 - iou_thresholded: 0.8764
# Epoch 87: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0266 - iou: 0.8250 - iou_thresholded: 0.8764 - val_loss: 0.1633 - val_iou: 0.5632 - val_iou_thresholded: 0.5933
# Epoch 88/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0246 - iou: 0.8379 - iou_thresholded: 0.8850
# Epoch 88: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 20s 68ms/step - loss: 0.0246 - iou: 0.8379 - iou_thresholded: 0.8850 - val_loss: 0.1787 - val_iou: 0.5242 - val_iou_thresholded: 0.5499
# Epoch 89/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0259 - iou: 0.8285 - iou_thresholded: 0.8781
# Epoch 89: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0259 - iou: 0.8285 - iou_thresholded: 0.8781 - val_loss: 0.1520 - val_iou: 0.5785 - val_iou_thresholded: 0.6084
# Epoch 90/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0256 - iou: 0.8292 - iou_thresholded: 0.8788
# Epoch 90: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0256 - iou: 0.8292 - iou_thresholded: 0.8788 - val_loss: 0.1693 - val_iou: 0.5479 - val_iou_thresholded: 0.5732
# Epoch 91/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0278 - iou: 0.8212 - iou_thresholded: 0.8715
# Epoch 91: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0278 - iou: 0.8212 - iou_thresholded: 0.8715 - val_loss: 0.1509 - val_iou: 0.5439 - val_iou_thresholded: 0.5747
# Epoch 92/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0247 - iou: 0.8368 - iou_thresholded: 0.8855
# Epoch 92: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0247 - iou: 0.8368 - iou_thresholded: 0.8855 - val_loss: 0.1737 - val_iou: 0.5583 - val_iou_thresholded: 0.5810
# Epoch 93/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0255 - iou: 0.8342 - iou_thresholded: 0.8823
# Epoch 93: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0255 - iou: 0.8342 - iou_thresholded: 0.8823 - val_loss: 0.1709 - val_iou: 0.5507 - val_iou_thresholded: 0.5716
# Epoch 94/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0254 - iou: 0.8300 - iou_thresholded: 0.8790
# Epoch 94: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 20s 68ms/step - loss: 0.0254 - iou: 0.8300 - iou_thresholded: 0.8790 - val_loss: 0.1834 - val_iou: 0.5615 - val_iou_thresholded: 0.5855
# Epoch 95/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0296 - iou: 0.8102 - iou_thresholded: 0.8643
# Epoch 95: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0296 - iou: 0.8102 - iou_thresholded: 0.8643 - val_loss: 0.1676 - val_iou: 0.5297 - val_iou_thresholded: 0.5606
# Epoch 96/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0253 - iou: 0.8331 - iou_thresholded: 0.8825
# Epoch 96: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0253 - iou: 0.8331 - iou_thresholded: 0.8825 - val_loss: 0.1650 - val_iou: 0.5462 - val_iou_thresholded: 0.5711
# Epoch 97/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0230 - iou: 0.8460 - iou_thresholded: 0.8900
# Epoch 97: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 62ms/step - loss: 0.0230 - iou: 0.8460 - iou_thresholded: 0.8900 - val_loss: 0.1449 - val_iou: 0.5748 - val_iou_thresholded: 0.6056
# Epoch 98/150
# 299/300 [============================>.] - ETA: 0s - loss: 0.0403 - iou: 0.7721 - iou_thresholded: 0.8405
# Epoch 98: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0402 - iou: 0.7723 - iou_thresholded: 0.8407 - val_loss: 0.1618 - val_iou: 0.5327 - val_iou_thresholded: 0.5667
# Epoch 99/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0264 - iou: 0.8264 - iou_thresholded: 0.8783
# Epoch 99: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0264 - iou: 0.8264 - iou_thresholded: 0.8783 - val_loss: 0.1566 - val_iou: 0.5475 - val_iou_thresholded: 0.5782
# Epoch 100/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0240 - iou: 0.8367 - iou_thresholded: 0.8858
# Epoch 100: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 20s 67ms/step - loss: 0.0240 - iou: 0.8367 - iou_thresholded: 0.8858 - val_loss: 0.1798 - val_iou: 0.5401 - val_iou_thresholded: 0.5653
# Epoch 101/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0252 - iou: 0.8364 - iou_thresholded: 0.8852
# Epoch 101: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 62ms/step - loss: 0.0252 - iou: 0.8364 - iou_thresholded: 0.8852 - val_loss: 0.1805 - val_iou: 0.5449 - val_iou_thresholded: 0.5712
# Epoch 102/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0234 - iou: 0.8455 - iou_thresholded: 0.8909
# Epoch 102: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0234 - iou: 0.8455 - iou_thresholded: 0.8909 - val_loss: 0.1921 - val_iou: 0.5355 - val_iou_thresholded: 0.5564
# Epoch 103/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0225 - iou: 0.8498 - iou_thresholded: 0.8940
# Epoch 103: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0225 - iou: 0.8498 - iou_thresholded: 0.8940 - val_loss: 0.1821 - val_iou: 0.5615 - val_iou_thresholded: 0.5812
# Epoch 104/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0215 - iou: 0.8518 - iou_thresholded: 0.8940
# Epoch 104: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0215 - iou: 0.8518 - iou_thresholded: 0.8940 - val_loss: 0.1800 - val_iou: 0.5446 - val_iou_thresholded: 0.5609
# Epoch 105/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0253 - iou: 0.8335 - iou_thresholded: 0.8818
# Epoch 105: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 24s 82ms/step - loss: 0.0253 - iou: 0.8335 - iou_thresholded: 0.8818 - val_loss: 0.1755 - val_iou: 0.5609 - val_iou_thresholded: 0.5856
# Epoch 106/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0229 - iou: 0.8478 - iou_thresholded: 0.8924
# Epoch 106: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0229 - iou: 0.8478 - iou_thresholded: 0.8924 - val_loss: 0.1747 - val_iou: 0.5588 - val_iou_thresholded: 0.5824
# Epoch 107/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0248 - iou: 0.8379 - iou_thresholded: 0.8855
# Epoch 107: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0248 - iou: 0.8379 - iou_thresholded: 0.8855 - val_loss: 0.1662 - val_iou: 0.5509 - val_iou_thresholded: 0.5696
# Epoch 108/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0224 - iou: 0.8479 - iou_thresholded: 0.8928
# Epoch 108: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0224 - iou: 0.8479 - iou_thresholded: 0.8928 - val_loss: 0.1703 - val_iou: 0.5766 - val_iou_thresholded: 0.6001
# Epoch 109/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0233 - iou: 0.8441 - iou_thresholded: 0.8887
# Epoch 109: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 20s 67ms/step - loss: 0.0233 - iou: 0.8441 - iou_thresholded: 0.8887 - val_loss: 0.1874 - val_iou: 0.5606 - val_iou_thresholded: 0.5810
# Epoch 110/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0226 - iou: 0.8509 - iou_thresholded: 0.8948
# Epoch 110: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 20s 65ms/step - loss: 0.0226 - iou: 0.8509 - iou_thresholded: 0.8948 - val_loss: 0.1700 - val_iou: 0.5665 - val_iou_thresholded: 0.5869
# Epoch 111/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0346 - iou: 0.7953 - iou_thresholded: 0.8529
# Epoch 111: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 19s 62ms/step - loss: 0.0346 - iou: 0.7953 - iou_thresholded: 0.8529 - val_loss: 0.1968 - val_iou: 0.4845 - val_iou_thresholded: 0.5230
# Epoch 112/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0313 - iou: 0.8097 - iou_thresholded: 0.8667
# Epoch 112: val_iou_thresholded did not improve from 0.61028
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0313 - iou: 0.8097 - iou_thresholded: 0.8667 - val_loss: 0.1358 - val_iou: 0.5789 - val_iou_thresholded: 0.6076
# Epoch 113/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0272 - iou: 0.8206 - iou_thresholded: 0.8720
# Epoch 113: val_iou_thresholded improved from 0.61028 to 0.62614, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0272 - iou: 0.8206 - iou_thresholded: 0.8720 - val_loss: 0.1401 - val_iou: 0.5958 - val_iou_thresholded: 0.6261
# Epoch 114/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0221 - iou: 0.8526 - iou_thresholded: 0.8967
# Epoch 114: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0221 - iou: 0.8526 - iou_thresholded: 0.8967 - val_loss: 0.1480 - val_iou: 0.5914 - val_iou_thresholded: 0.6174
# Epoch 115/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0214 - iou: 0.8560 - iou_thresholded: 0.8982
# Epoch 115: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0214 - iou: 0.8560 - iou_thresholded: 0.8982 - val_loss: 0.1605 - val_iou: 0.5702 - val_iou_thresholded: 0.5912
# Epoch 116/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0207 - iou: 0.8580 - iou_thresholded: 0.8993
# Epoch 116: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0207 - iou: 0.8580 - iou_thresholded: 0.8993 - val_loss: 0.1491 - val_iou: 0.5852 - val_iou_thresholded: 0.6065
# Epoch 117/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0215 - iou: 0.8547 - iou_thresholded: 0.8977
# Epoch 117: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0215 - iou: 0.8547 - iou_thresholded: 0.8977 - val_loss: 0.1645 - val_iou: 0.5843 - val_iou_thresholded: 0.6070
# Epoch 118/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0219 - iou: 0.8549 - iou_thresholded: 0.8975
# Epoch 118: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0219 - iou: 0.8549 - iou_thresholded: 0.8975 - val_loss: 0.2037 - val_iou: 0.5325 - val_iou_thresholded: 0.5616
# Epoch 119/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0257 - iou: 0.8329 - iou_thresholded: 0.8817
# Epoch 119: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 23s 76ms/step - loss: 0.0257 - iou: 0.8329 - iou_thresholded: 0.8817 - val_loss: 0.1544 - val_iou: 0.5978 - val_iou_thresholded: 0.6216
# Epoch 120/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0210 - iou: 0.8537 - iou_thresholded: 0.8965
# Epoch 120: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0210 - iou: 0.8537 - iou_thresholded: 0.8965 - val_loss: 0.1724 - val_iou: 0.5693 - val_iou_thresholded: 0.5906
# Epoch 121/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0205 - iou: 0.8586 - iou_thresholded: 0.8994
# Epoch 121: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0205 - iou: 0.8586 - iou_thresholded: 0.8994 - val_loss: 0.2071 - val_iou: 0.5628 - val_iou_thresholded: 0.5835
# Epoch 122/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0220 - iou: 0.8517 - iou_thresholded: 0.8949
# Epoch 122: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 18s 61ms/step - loss: 0.0220 - iou: 0.8517 - iou_thresholded: 0.8949 - val_loss: 0.1557 - val_iou: 0.5872 - val_iou_thresholded: 0.6136
# Epoch 123/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0207 - iou: 0.8601 - iou_thresholded: 0.9009
# Epoch 123: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 18s 62ms/step - loss: 0.0207 - iou: 0.8601 - iou_thresholded: 0.9009 - val_loss: 0.1968 - val_iou: 0.5585 - val_iou_thresholded: 0.5770
# Epoch 124/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0251 - iou: 0.8386 - iou_thresholded: 0.8852
# Epoch 124: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 20s 65ms/step - loss: 0.0251 - iou: 0.8386 - iou_thresholded: 0.8852 - val_loss: 0.1746 - val_iou: 0.5336 - val_iou_thresholded: 0.5557
# Epoch 125/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0237 - iou: 0.8444 - iou_thresholded: 0.8906
# Epoch 125: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 21s 70ms/step - loss: 0.0237 - iou: 0.8444 - iou_thresholded: 0.8906 - val_loss: 0.1549 - val_iou: 0.5798 - val_iou_thresholded: 0.6010
# Epoch 126/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0211 - iou: 0.8597 - iou_thresholded: 0.9006
# Epoch 126: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 22s 74ms/step - loss: 0.0211 - iou: 0.8597 - iou_thresholded: 0.9006 - val_loss: 0.1617 - val_iou: 0.5639 - val_iou_thresholded: 0.5830
# Epoch 127/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0239 - iou: 0.8447 - iou_thresholded: 0.8891
# Epoch 127: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0239 - iou: 0.8447 - iou_thresholded: 0.8891 - val_loss: 0.1898 - val_iou: 0.5200 - val_iou_thresholded: 0.5444
# Epoch 128/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0217 - iou: 0.8510 - iou_thresholded: 0.8950
# Epoch 128: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0217 - iou: 0.8510 - iou_thresholded: 0.8950 - val_loss: 0.1583 - val_iou: 0.5845 - val_iou_thresholded: 0.6062
# Epoch 129/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0214 - iou: 0.8568 - iou_thresholded: 0.8989
# Epoch 129: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 21s 69ms/step - loss: 0.0214 - iou: 0.8568 - iou_thresholded: 0.8989 - val_loss: 0.1657 - val_iou: 0.5659 - val_iou_thresholded: 0.5891
# Epoch 130/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0203 - iou: 0.8607 - iou_thresholded: 0.9020
# Epoch 130: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 20s 67ms/step - loss: 0.0203 - iou: 0.8607 - iou_thresholded: 0.9020 - val_loss: 0.1790 - val_iou: 0.5772 - val_iou_thresholded: 0.5991
# Epoch 131/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0194 - iou: 0.8671 - iou_thresholded: 0.9068
# Epoch 131: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 63ms/step - loss: 0.0194 - iou: 0.8671 - iou_thresholded: 0.9068 - val_loss: 0.1676 - val_iou: 0.5769 - val_iou_thresholded: 0.5949
# Epoch 132/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0185 - iou: 0.8689 - iou_thresholded: 0.9064
# Epoch 132: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0185 - iou: 0.8689 - iou_thresholded: 0.9064 - val_loss: 0.1830 - val_iou: 0.5639 - val_iou_thresholded: 0.5820
# Epoch 133/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0301 - iou: 0.8241 - iou_thresholded: 0.8764
# Epoch 133: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0301 - iou: 0.8241 - iou_thresholded: 0.8764 - val_loss: 0.1658 - val_iou: 0.5557 - val_iou_thresholded: 0.5789
# Epoch 134/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0215 - iou: 0.8553 - iou_thresholded: 0.8991
# Epoch 134: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 21s 71ms/step - loss: 0.0215 - iou: 0.8553 - iou_thresholded: 0.8991 - val_loss: 0.1574 - val_iou: 0.5676 - val_iou_thresholded: 0.5938
# Epoch 135/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0193 - iou: 0.8646 - iou_thresholded: 0.9049
# Epoch 135: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0193 - iou: 0.8646 - iou_thresholded: 0.9049 - val_loss: 0.1723 - val_iou: 0.5732 - val_iou_thresholded: 0.5927
# Epoch 136/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0213 - iou: 0.8609 - iou_thresholded: 0.9012
# Epoch 136: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0213 - iou: 0.8609 - iou_thresholded: 0.9012 - val_loss: 0.1606 - val_iou: 0.5841 - val_iou_thresholded: 0.6104
# Epoch 137/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0219 - iou: 0.8562 - iou_thresholded: 0.8985
# Epoch 137: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 65ms/step - loss: 0.0219 - iou: 0.8562 - iou_thresholded: 0.8985 - val_loss: 0.1421 - val_iou: 0.5867 - val_iou_thresholded: 0.6207
# Epoch 138/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0247 - iou: 0.8388 - iou_thresholded: 0.8872
# Epoch 138: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 21s 69ms/step - loss: 0.0247 - iou: 0.8388 - iou_thresholded: 0.8872 - val_loss: 0.1761 - val_iou: 0.5405 - val_iou_thresholded: 0.5590
# Epoch 139/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0200 - iou: 0.8656 - iou_thresholded: 0.9059
# Epoch 139: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 21s 70ms/step - loss: 0.0200 - iou: 0.8656 - iou_thresholded: 0.9059 - val_loss: 0.1882 - val_iou: 0.5511 - val_iou_thresholded: 0.5698
# Epoch 140/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0194 - iou: 0.8695 - iou_thresholded: 0.9079
# Epoch 140: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0194 - iou: 0.8695 - iou_thresholded: 0.9079 - val_loss: 0.2019 - val_iou: 0.5441 - val_iou_thresholded: 0.5575
# Epoch 141/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0189 - iou: 0.8697 - iou_thresholded: 0.9086
# Epoch 141: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 19s 64ms/step - loss: 0.0189 - iou: 0.8697 - iou_thresholded: 0.9086 - val_loss: 0.1936 - val_iou: 0.5476 - val_iou_thresholded: 0.5634
# Epoch 142/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0190 - iou: 0.8672 - iou_thresholded: 0.9061
# Epoch 142: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 20s 68ms/step - loss: 0.0190 - iou: 0.8672 - iou_thresholded: 0.9061 - val_loss: 0.2007 - val_iou: 0.5435 - val_iou_thresholded: 0.5574
# Epoch 143/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0178 - iou: 0.8746 - iou_thresholded: 0.9106
# Epoch 143: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 22s 73ms/step - loss: 0.0178 - iou: 0.8746 - iou_thresholded: 0.9106 - val_loss: 0.2152 - val_iou: 0.5276 - val_iou_thresholded: 0.5434
# Epoch 144/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0201 - iou: 0.8663 - iou_thresholded: 0.9050
# Epoch 144: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 20s 67ms/step - loss: 0.0201 - iou: 0.8663 - iou_thresholded: 0.9050 - val_loss: 0.1799 - val_iou: 0.5666 - val_iou_thresholded: 0.5886
# Epoch 145/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0205 - iou: 0.8602 - iou_thresholded: 0.9009
# Epoch 145: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 20s 66ms/step - loss: 0.0205 - iou: 0.8602 - iou_thresholded: 0.9009 - val_loss: 0.1718 - val_iou: 0.5514 - val_iou_thresholded: 0.5691
# Epoch 146/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0193 - iou: 0.8689 - iou_thresholded: 0.9071
# Epoch 146: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 22s 72ms/step - loss: 0.0193 - iou: 0.8689 - iou_thresholded: 0.9071 - val_loss: 0.1560 - val_iou: 0.5865 - val_iou_thresholded: 0.6091
# Epoch 147/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0195 - iou: 0.8684 - iou_thresholded: 0.9068
# Epoch 147: val_iou_thresholded did not improve from 0.62614
# 300/300 [==============================] - 23s 78ms/step - loss: 0.0195 - iou: 0.8684 - iou_thresholded: 0.9068 - val_loss: 0.1942 - val_iou: 0.5519 - val_iou_thresholded: 0.5696
# Epoch 148/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0198 - iou: 0.8653 - iou_thresholded: 0.9050
# Epoch 148: val_iou_thresholded improved from 0.62614 to 0.63664, saving model to /content/drive/MyDrive/TACO features/widen_param_0.2/segm_model.h5
# 300/300 [==============================] - 25s 84ms/step - loss: 0.0198 - iou: 0.8653 - iou_thresholded: 0.9050 - val_loss: 0.1614 - val_iou: 0.6132 - val_iou_thresholded: 0.6366
# Epoch 149/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0208 - iou: 0.8609 - iou_thresholded: 0.9009
# Epoch 149: val_iou_thresholded did not improve from 0.63664
# 300/300 [==============================] - 21s 70ms/step - loss: 0.0208 - iou: 0.8609 - iou_thresholded: 0.9009 - val_loss: 0.1900 - val_iou: 0.5630 - val_iou_thresholded: 0.5843
# Epoch 150/150
# 300/300 [==============================] - ETA: 0s - loss: 0.0215 - iou: 0.8556 - iou_thresholded: 0.8978
# Epoch 150: val_iou_thresholded did not improve from 0.63664
# 300/300 [==============================] - 24s 80ms/step - loss: 0.0215 - iou: 0.8556 - iou_thresholded: 0.8978 - val_loss: 0.1712 - val_iou: 0.5651 - val_iou_thresholded: 0.5876

# %%
history_path = "{}/{}/{}".format(features_path,"widen_param_0.2","segm_model_history.csv")

# %%
hist_df = pd.DataFrame(history.history)
with open(history_path, mode='w') as f:
    hist_df.to_csv(f)

# %% [markdown]
# By the 150th epoch, the highest thresholded IOU achieved on the validation set is close to **64%**.
#
# With an increasing number of epochs, we can see that the training loss keeps decreasing while the validation loss hovers at around the same level (loss=0.15). Our training IOU metric also keeps increasing, which shows that the model is learning weights that almost perfectly segment the bottles in the training set. The thresholded IOU on the validations set, however, has stopped increasing after about 50 epochs, a sign of overfitting.

# %%
fig, (ax1, ax2) = plt.subplots(nrows=1, ncols=2, figsize=(12, 4))

ax1.set_title("Loss: {:.4f}".format(history.history["val_loss"][-1]))
ax1.plot(history.history["val_loss"], label="validation")
ax1.plot(history.history["loss"], label="training")
ax1.set_xlabel("Epochs")
ax1.legend()

ax2.set_title("Thresholded IOU: {:.2f}%".format(history.history["val_iou_thresholded"][-1] * 100))
ax2.plot(history.history["val_iou_thresholded"], label="validation")
ax2.plot(history.history["iou_thresholded"], label="training")
ax2.set_xlabel("Epochs")
ax2.legend()

plt.show()

# %% [markdown]
# ## 8) Assessing performance on the test set

# %% [markdown]
# Finally, we can segment the images in our test set using the model we just trained.

# %%
unet_model.load_weights(model_path)

# %%
y_pred = unet_model.predict(x_test)
# Out:
# 1/1 [==============================] - 0s 38ms/step

# %% [markdown]
# In order to use the use the 'iou_thresholded' function, we need to convert both the masks and the prediction arrays into floats. We then proceed to predict the thresholded IOUs for the 25 images in the test set.

# %%
y_pred = y_pred.astype(np.float32) #y_pred are the predicted image masks on the testing set
y_test_float = y_test.astype(np.float32) #y_test are the ground truth masks aside for the testing set

# %%
test_set_thresholded_ious = [iou_thresholded(y_true=x,y_pred=y).numpy() for x, y in zip(y_test_float,y_pred)]

# %%
pd.Series(test_set_thresholded_ious).describe()
# Out:
# count    25.000000
# mean      0.721343
# std       0.287215
# min       0.000281
# 25%       0.613734
# 50%       0.847042
# 75%       0.927617
# max       0.976136
# dtype: float64

# %% [markdown]
# The thresholded IOUs range from 0 (no overlap) to 0.98 (almost perfect overlap), and the average on the test set is 72%. We proceed to visualize the worst and the best prediction.

# %%
lowest_iou = pd.Series(test_set_thresholded_ious).idxmin()

print("The highest IOU in the test set is {:.2f}".format(test_set_thresholded_ious[lowest_iou]))
# Out:
# The highest IOU in the test set is 0.00

# %% [markdown]
# We can see that, in the case of the worst prediction, the bottle is surrounded by wooden poles covered in markings - which do slightly resemble the shape of a bottle. Moreover, the bottle is relatively small and is partially covered by a small bush.

# %%
plot_imgs(org_imgs=np.expand_dims(x_test[lowest_iou,:,:,:],axis=0),
          mask_imgs=np.expand_dims(y_test[lowest_iou,:,:,:],axis=0),
          pred_imgs=np.expand_dims(y_pred[lowest_iou,:,:,:],axis=0), nm_img_to_plot=1)

# %%
highest_iou = pd.Series(test_set_thresholded_ious).idxmax()

print("The highest IOU in the test set is {:.2f}".format(test_set_thresholded_ious[highest_iou]))
# Out:
# The highest IOU in the test set is 0.98

# %% [markdown]
# In contrast, the image with the highest IOU is a much 'cleaner' image where the contours of the bottle are clearly discernible and there are no background elements which might lead pixels to being misclassified.

# %%
plot_imgs(org_imgs=np.expand_dims(x_test[highest_iou,:,:,:],axis=0),
          mask_imgs=np.expand_dims(y_test[highest_iou,:,:,:],axis=0),
          pred_imgs=np.expand_dims(y_pred[highest_iou,:,:,:],axis=0), nm_img_to_plot=1)

# %% [markdown]
# ## 9) Summary

# %% [markdown]
# To summarise the three analyses carried out in this capstone project:
#
# * We have developed a machine learning model based on logistic regression that correctly **classifies** 76% of images belonging to one of **five classes**: plastic film, carton, bottles, cans and cups. Moreover, if this model predicts that an object is a bottle, there is an 87% likelihood that this is true.
#
# * Having collected and sorted through our objects to pick out the real bottles (for example, discarding any cups wrongly classified as bottles), we can use our second machine learning model to **classify the material** of the bottle (either glass or plastic). This second model will accurately classify 86% of the bottles we have set aside.
#
# * Finally, we have also developed a model that could help us (or a recycling robot) identify exactly where the bottles are located in a picture (or the robot's visual field). This is a process called object **segmentation**. This neural network's prediction is measured using the 'intersection over union' metric, which can range from 0 (no overlap) to 1 (perfect overlap). On images of bottles captured relatively close-up, our model achieves a high score of about 0.7.
